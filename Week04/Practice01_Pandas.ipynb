# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.5 MB 13.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 510 kB 35.9 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/Users/henry/miniconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
pd.__version__
# Out:
# '1.2.3'

# %%
data = [1, 2, 3, 4]
index = ['a', 'b', 'c', 'd']
pd.Series(data=data, index=index)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
a = pd.Series(data=data, index=index)
type(a)
# Out:
# pandas.core.series.Series

# %%
data = {'Hello':[1,2,3,4], 'Handong':['a','b','c','d']}
index = ['A', 'B', 'C', 'D']
data_df = pd.DataFrame(data=data, index=index)
data_df
# Out:
#    Hello Handong
# A      1       a
# B      2       b
# C      3       c
# D      4       d

# %%
import numpy as np

data = np.ones((5,3))
df = pd.DataFrame(data=data)

# %%
df = pd.read_csv('titanic_train.csv', index_col='PassengerId')
df.head(1)
# Out:
#              Survived  Pclass                     Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#              Parch     Ticket  Fare Cabin Embarked
# PassengerId
# 1                0  A/5 21171  7.25   NaN        S

# %%
df.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
df.tail(2)
# Out:
#              Survived  Pclass                   Name   Sex   Age  SibSp  \
# PassengerId
# 890                 1       1  Behr, Mr. Karl Howell  male  26.0      0
# 891                 0       3    Dooley, Mr. Patrick  male  32.0      0
#
#              Parch  Ticket   Fare Cabin Embarked
# PassengerId
# 890              0  111369  30.00  C148        C
# 891              0  370376   7.75   NaN        Q

# %%
df.sample(2)
# Out:
#              Survived  Pclass                     Name     Sex  Age  SibSp  \
# PassengerId
# 197                 0       3      Mernagh, Mr. Robert    male  NaN      0
# 307                 1       1  Fleming, Miss. Margaret  female  NaN      0
#
#              Parch  Ticket      Fare Cabin Embarked
# PassengerId
# 197              0  368703    7.7500   NaN        Q
# 307              0   17421  110.8833   NaN        C

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
df.mean()
# Out:
# Survived     0.383838
# Pclass       2.308642
# Age         29.699118
# SibSp        0.523008
# Parch        0.381594
# Fare        32.204208
# dtype: float64

# %%
df.groupby("Pclass").mean()
# Out:
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       0.629630  38.233441  0.416667  0.356481  84.154687
# 2       0.472826  29.877630  0.402174  0.380435  20.662183
# 3       0.242363  25.140620  0.615071  0.393075  13.675550

# %%
df.groupby(['Survived', 'Pclass']).mean()
# Out:
#                        Age     SibSp     Parch       Fare
# Survived Pclass
# 0        1       43.695312  0.287500  0.300000  64.684008
#          2       33.544444  0.319588  0.144330  19.412328
#          3       26.555556  0.672043  0.384409  13.669364
# 1        1       35.368197  0.492647  0.389706  95.608029
#          2       25.901566  0.494253  0.643678  22.055700
#          3       20.646118  0.436975  0.420168  13.694887

# %%
df.loc[0:5,"Name"]
# Out:
# PassengerId
# 1                              Braund, Mr. Owen Harris
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                               Heikkinen, Miss. Laina
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
df.iloc[0:2, 0:2]
# Out:
#              Survived  Pclass
# PassengerId
# 1                   0       3
# 2                   1       1

# %%
df[['Age','Survived']]
# Out:
#               Age  Survived
# PassengerId
# 1            22.0         0
# 2            38.0         1
# 3            26.0         1
# 4            35.0         1
# 5            35.0         0
# ...           ...       ...
# 887          27.0         0
# 888          19.0         1
# 889           NaN         0
# 890          26.0         1
# 891          32.0         0
#
# [891 rows x 2 columns]

# %%
mask = (df.Survived == 0)
df[mask][:5]
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris  male  22.0
# 5                   0       3        Allen, Mr. William Henry  male  35.0
# 6                   0       3                Moran, Mr. James  male   NaN
# 7                   0       1         McCarthy, Mr. Timothy J  male  54.0
# 8                   0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 5                0      0     373450   8.0500   NaN        S
# 6                0      0     330877   8.4583   NaN        Q
# 7                0      0      17463  51.8625   E46        S
# 8                3      1     349909  21.0750   NaN        S

# %%
df['new'] = 10;
df.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked  new
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S   10
# 2                1      0   PC 17599  71.2833   C85        C   10

# %%
df['family'] = df['SibSp'] + df['Parch']
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  new  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S   10
# 2                1      0          PC 17599  71.2833   C85        C   10
# ...

# %%
df.drop(columns=['new', 'family'],inplace=True)

# %%
df[0:2]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
data = np.zeros(len(df))
index = np.array(range(1,len(df)+1))

new_ser= pd.Series(data, name = 'zeros', index=index)
new_df = pd.concat(objs=[df, new_ser], axis=1)

new_df.head(5)
# Out:
#    Survived  Pclass                                               Name  \
# 1         0       3                            Braund, Mr. Owen Harris
# 2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       3                             Heikkinen, Miss. Laina
# 4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  zeros
# 1    male  22.0      1      0         A/5 21171   7.2500   NaN        S    0.0
# 2  female  38.0      1      0          PC 17599  71.2833   C85        C    0.0
# 3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S    0.0
# 4  female  35.0      1      0            113803  53.1000  C123        S    0.0
# 5    male  35.0      0      0            373450   8.0500   NaN        S    0.0

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.rename(columns = {"Age":"How old"}, inplace=True)
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'How old', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
df_temp = df.copy()
df_temp.reset_index(drop = True) # if False, it doesn’t drop PassengerId
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex  How old  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df[df['How old'].isnull()]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 6                   0       3                          Moran, Mr. James
# 18                  1       2              Williams, Mr. Charles Eugene
# 20                  1       3                   Masselmani, Mrs. Fatima
# 27                  0       3                   Emir, Mr. Farred Chehab
# 29                  1       3             O'Dwyer, Miss. Ellen "Nellie"
# ...               ...     ...                                       ...
# 860                 0       3                          Razi, Mr. Raihed
# 864                 0       3         Sage, Miss. Dorothy Edith "Dolly"
# 869                 0       3               van Melkebeke, Mr. Philemon
# 879                 0       3                        Laleff, Mr. Kristo
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#                 Sex  How old  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
print('number of null data in Age column: ', len(df[df['How old'].isnull()]))

age_mean = df['How old'].mean()
df['How old'].fillna(value=age_mean, inplace=True) # fill null value with age_mean

print('number of null data in Age column: ', len(df[df['How old'].isnull()]))
# Out:
# number of null data in Age column:  177
# number of null data in Age column:  0

# %%
df['Sex']=df['Sex'].apply(lambda x: 0 if x == 'male' else 1)
df.head(3)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name  Sex  How old  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0     22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    1     38.0
# 3                                       Heikkinen, Miss. Laina    1     26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df = df_temp.copy()

# %%
def sex2idx(x):
    return 0 if x == 'male' else 1
df['Sex'] = df['Sex'].apply(sex2idx)
df.head(3)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name  Sex  How old  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0     22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    1     38.0
# 3                                       Heikkinen, Miss. Laina    1     26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.to_csv('titanic_tocsv.csv')

# %% [markdown]
# # Exercise 1 - filling in missing values

# %%
import pandas as pd
df = pd.read_csv('titanic_train.csv', index_col='PassengerId')

"""
WRITE THE CODE
"""
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64
#
# Before --------------------------
#                Survived  Pclass                           Name     Sex  Age  \
# PassengerId
# 6                   0       3               Moran, Mr. James    male  NaN
# 18                  1       2   Williams, Mr. Charles Eugene    male  NaN
# 20                  1       3        Masselmani, Mrs. Fatima  female  NaN
# 27                  0       3        Emir, Mr. Farred Chehab    male  NaN
# 29                  1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#              SibSp  Parch  Ticket     Fare Cabin Embarked
# PassengerId
# 6                0      0  330877   8.4583   NaN        Q
# 18               0      0  244373  13.0000   NaN        S
# 20               0      0    2649   7.2250   NaN        C
# ...

# %% [markdown]
# ## Exerciese 2 - number of survivals per sex and passenger class

# %%
"""
WRITE THE CODE
"""
# Out:
# Sex     Pclass
# female  1         91
#         2         70
#         3         72
# male    1         45
#         2         17
#         3         47
# Name: Survived, dtype: int64

# %%
"""
WRITE THE CODE
"""
# Out:
# group: ('female', 1) => 91
# group: ('female', 2) => 70
# group: ('female', 3) => 72
# group: ('male', 1) => 45
# group: ('male', 2) => 17
# group: ('male', 3) => 47

# %%
"""
WRITE THE CODE
"""
# Out:
# group: ('female', 1) => 3
# group: ('female', 2) => 6
# group: ('female', 3) => 72
# group: ('male', 1) => 77
# group: ('male', 2) => 91
# group: ('male', 3) => 300

# %%
"""
WRITE THE CODE
"""
# Out:
# 94
# 76
# 144
# 122
# 108
# 347
